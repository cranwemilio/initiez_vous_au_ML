# %%
# On importe les librairies dont on aura besoin pour ce tp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# On charge le dataset
house_data = pd.read_csv('https://raw.githubusercontent.com/cranwemilio/initiez_vous_au_ML/main/house_data2.csv')

print(house_data.info())
for elem in house_data.columns:
  house_data=house_data[house_data[elem].notnull()]
house_data=house_data.reset_index(drop=True)
print(house_data.info())
house_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 827 entries, 0 to 826
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   price           827 non-null    int64
#  1   surface         822 non-null    float64
#  2   arrondissement  822 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 19.5 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 822 entries, 0 to 821
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   price           822 non-null    int64
#  1   surface         822 non-null    float64
#  2   arrondissement  822 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 19.4 KB
# None
#      price  surface  arrondissement
# 0     1820    46.10             1.0
# 1     1750    41.00             1.0
# 2     1900    55.00             1.0
# 3     1950    46.00             1.0
# ...

# %%
# On affiche le nuage de points dont on dispose
plt.plot(house_data['surface'], house_data['price'], 'ro', markersize=4)
plt.show()

# %%
house_data[130:150]
# Out:
#      price  surface  arrondissement
# 130   1650    40.00             1.0
# 131   2000    35.00             1.0
# 132   3020    84.00             1.0
# 133   4500   115.00             1.0
# 134  15000   347.00             1.0
# 135    990    30.00             1.0
# 136   1101    34.64             1.0
# 137   2999    76.29             1.0
# 138   3490   109.55             1.0
# 139   4722   160.00             1.0
# 140   6800   200.00             1.0
# 141  15000   347.00             1.0
# 142  21000   180.00             1.0
# 143    820    25.00             1.0
# 144   1100    37.00             1.0
# 145   2750    50.00             1.0
# 146   3000    50.00             1.0
# 147   3750    70.00             1.0
# 148   3140   100.00             1.0
# 149    980    25.50             1.0

# %%
df = house_data[house_data['price'] < 10000]
df=df.reset_index(drop=True)
print(df.info())
df[df['surface'].notnull()]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 813 entries, 0 to 812
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   price           813 non-null    int64
#  1   surface         813 non-null    float64
#  2   arrondissement  813 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 19.2 KB
# None
#      price  surface  arrondissement
# 0     1820    46.10             1.0
# 1     1750    41.00             1.0
# 2     1900    55.00             1.0
# 3     1950    46.00             1.0
# 4     1950    49.00             1.0
# ..     ...      ...             ...
# 808    850    35.00            10.0
# 809    700    10.00            10.0
# 810   1280    34.00            10.0
# 811   1545    65.00            10.0
# 812   1000    21.43            10.0
#
# [813 rows x 3 columns]

# %%
# On décompose le dataset et on le transforme en matrices pour pouvoir effectuer notre calcul
X = np.array([np.ones(house_data.shape[0]), house_data['surface'].values]).T
y = np.array(house_data['price']).T

# %%
plt.xlabel('Surface')
plt.ylabel('price')

plt.plot(house_data['surface'], house_data['price'], 'ro', markersize=4)

# On affiche la droite entre 0 et 250
plt.plot([0,250], [theta.item(0),theta.item(0) + 250 * theta.item(1)], linestyle='--', c='#000000')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-9796384c973a> in <module>()
#       5
#       6 # On affiche la droite entre 0 et 250
# ----> 7 plt.plot([0,250], [theta.item(0),theta.item(0) + 250 * theta.item(1)], linestyle='--', c='#000000')
#       8
#       9 plt.show()
#
# NameError: name 'theta' is not defined

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
regr.fit(X, y)
regr.predict(<des données de test>)
# Out:
# LinearRegression()
